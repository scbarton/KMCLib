# %% [markdown]
# # KMClib- ZGB model

# %% [markdown]
# This notebook reproduces Fig. 4 of [R. M. Ziff, E. Gulari, and Y. Barshad, Phys. Rev. Lett., 56, 2553–2556 (1986).](http://doi.org/10.1103/PhysRevLett.56.2553)
#
#  * uses [KMCLib as forked by scbarton](https://github.com/scbarton/KMCLib-scb)
#  * requires [pandas](https://pandas.pydata.org)
#
# This model simulates CO oxidation on a surface modeled as a rectangular grid. Only adsorption and reaction processes are considered, the atmosphere is assumed to be composed of only CO and O<sub>2</sub>, and oxygen adsorption is treated as dissociative. The surface oxidation reaction is considered fast, so that the overall rate is adsorption limited.  The reaction is oxygen poisoned at low CO partial pressure and CO poisoned at high CO partial pressure.

# %%
# %pylab inline
import random
from __future__ import division
from KMCLib import *
import pandas as pd
from copy import deepcopy
# Out:
# Populating the interactive namespace from numpy and matplotlib
# # -----------------------------------------------------------------------------
# # KMCLib version 2.0-a1
# # Distributed under the GPLv3 license
# # Copyright (C)  2012-2016  Mikael Leetmaa
# # Developed by Mikael Leetmaa <leetmaa@kth.se>
# #
# # This program is distributed in the hope that it will be useful
# # but WITHOUT ANY WARRANTY; without even the implied warranty of
# # MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
# # LICENSE and README files, and the source code, for details.
# #
# # You should have received a copy of the GNU General Public License version 3
# # (GPLv3) along with this program. If not, see <http://www.gnu.org/licenses/>.
# # -----------------------------------------------------------------------------

# %% [markdown]
# ## Parameters

# %%
N=100     # size of domain
ptot=1.0  # gas total pressure in atm
yCO=0.5   # mole fraction CO in gas phase
yO2= 1.0 - yCO    # mole fraction O2 in gas phase

# %% [markdown]
# ## Rate Constants

# %%
class Struct(): pass
k=Struct()

k.COads=yCO*ptot
k.O2ads=yO2*ptot
k.s= 1000.

k0=deepcopy(k)  # Backup baseline k

# %% [markdown]
# ## Initial Configuration

# %%
# Unit Cell
cell_vectors = [[   1.000000e+00,   0.000000e+00,   0.000000e+00],
                [   0.000000e+00,   1.000000e+00,   0.000000e+00],
                [   0.000000e+00,   0.000000e+00,   1.000000e+00]]
basis_points = [[   0.000000e+00,   0.000000e+00,   0.000000e+00]]
unit_cell = KMCUnitCell(cell_vectors=cell_vectors,
                        basis_points=basis_points)

# Define the lattice.
lattice = KMCLattice(unit_cell=unit_cell,
                 repetitions=(N,N,1),
                 periodic=(True, True, False))
# Generate the initial types.
possible_types=['O','CO','S']

# initially empty surface
typesinit = ['S']*(N**2)

# random coverage
# types = [random.choice(possible_types) for ii in range(N**2)]

# %% [markdown]
# ## Interactions

# %%
def interactions():
    from collections import OrderedDict
    coordinates = [[   0.000000e+00,   0.000000e+00,   0.000000e+00]]
    process=OrderedDict()

    # CO Adsorption
    process['COads'] = KMCProcess(coordinates=coordinates,
                       elements_before=['S'],
                       elements_after=['CO'],
                       basis_sites=[0],
                       rate_constant=k.COads )

    # O2 Dissociative Adsorption
    process['O2adsU'] = KMCProcess(coordinates=[[0.,0.,0.],[1.,0.,0.]],
                       elements_before=['S','S'], elements_after=['O','O'],
                       basis_sites=[0], rate_constant=k.O2ads/4.0)

    process['O2adsD'] = KMCProcess(coordinates=[[0.,0.,0.],[-1.,0.,0.]],
                       elements_before=['S','S'], elements_after=['O','O'],
                       basis_sites=[0], rate_constant=k.O2ads/4.0)

    process['O2adsL'] = KMCProcess(coordinates=[[0.,0.,0.],[0.,-1.,0.]],
                       elements_before=['S','S'], elements_after=['O','O'],
                       basis_sites=[0], rate_constant=k.O2ads/4.0)

    process['O2adsR'] = KMCProcess(coordinates=[[0.,0.,0.],[0.,1.,0.]],
                       elements_before=['S','S'], elements_after=['O','O'],
                       basis_sites=[0], rate_constant=k.O2ads/4.0)

    # CO + O -> CO2 oxidation process
    process['oxidationU'] =KMCProcess(coordinates=[[0.,0.,0.],[1.,0.,0.]],
                       elements_before=['CO','O'], elements_after=['S','S'],
                       basis_sites=[0], rate_constant=k.s/4.0)

    process['oxidationD'] =KMCProcess(coordinates=[[0.,0.,0.],[-1.,0.,0.]],
                       elements_before=['CO','O'], elements_after=['S','S'],
                       basis_sites=[0], rate_constant=k.s/4.0)

    process['oxidationL'] =KMCProcess(coordinates=[[0.,0.,0.],[0.,-1.,0.]],
                       elements_before=['CO','O'], elements_after=['S','S'],
                       basis_sites=[0], rate_constant=k.s/4.0)

    process['oxidationR'] =KMCProcess(coordinates=[[0.,0.,0.],[0.,1.,0.]],
                       elements_before=['CO','O'], elements_after=['S','S'],
                       basis_sites=[0], rate_constant=k.s/4.0)
    
    # remove processes with zero rate constant
    for key, p in process.items():
        if p.rateConstant()==0:
            del process[key]
    
    return process

# %% [markdown]
# ## Main calculation

# %%
def ZGBrun(label='zgb_traj'):
    
    # Setup the configuration.
    configuration = KMCConfiguration(lattice=lattice,
                             types=typesinit,
                             possible_types=possible_types)   

    # Create the interactions object
    interactions = KMCInteractions(processes=process.values(),
                                   implicit_wildcards=True)

    # Create the model.
    model = KMCLatticeModel(configuration, interactions)

    #process analysis
    process_analysis = ProcessStatistics(processes=range(len(process.values())))

    # Define the parameters.
    control_parameters = KMCControlParameters(number_of_steps=1000000,
                                              dump_interval=10000,
                                              analysis_interval=1)
    
    # Run the simulation and save trajectory 
    # Here we catch errors in the case where the surface is poisoned and
    # no processes are possible.
    
    error_val=0
    
    try:
        model.run(control_parameters, trajectory_filename=label+'.py',
                  analysis=[process_analysis])
    except Exception as e:
       error_val=1
        
    # load the trajectory
    trj={}
    execfile(label+'.py',trj)
           
    # surface coverages for every species
    theta={}
    for s in possible_types:
        theta[s]=[sum(array(t)==s)/len(t) for t in trj['types'] ]
    trj['theta']=theta    
    
    # reaction rates for every process
    rT=process_analysis.proc_data.transpose()
    d={key:rT[ii] for ii, key in enumerate(process.keys())}
    df=pd.DataFrame(d,index=process_analysis.time)
    df.index.name='Time'
    df['O2ads']=df.filter(regex='O2ads').sum(axis=1)
    df['O2des']=df.filter(regex='O2des').sum(axis=1)
    df['oxidation']=df.filter(regex='oxidation').sum(axis=1)

    return trj, df, error_val

# %% [markdown]
# ## yCO sweep

# %%
typesinit = ['S']*(N**2)  # initially empty surface
k=deepcopy(k0)   # reset k to baseline

yv=linspace(0.3,0.6,31)
QO,QCO,TOF= [],[],[]

for yCO in yv:
    
    yO2=1-yCO
    k.COads=yCO*ptot
    k.O2ads=yO2*ptot
    
    process=interactions()
    trj, rates, error_val = ZGBrun()
    
    Nt=len(trj['types'])
    
    if error_val==1:
        QO  += [ trj['theta']['O' ][Nt-1] ]
        QCO += [ trj['theta']['CO'][Nt-1] ]

        TOF += [0.0]
    else:
        QO  += [ mean(trj['theta']['O' ][int(0.9*Nt):Nt]) ]
        QCO += [ mean(trj['theta']['CO'][int(0.9*Nt):Nt]) ]

        Na=len(rates.index)
        TOF += [ mean(rates['oxidation'][int(0.9*Na):Na])/N**2 ]
# Out:
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.6646242326e+00
#  KMCLib: 20000 steps executed. time:     5.9323167952e+00
#  KMCLib: 30000 steps executed. time:     1.4214588973e+01
#  KMCLib: 40000 steps executed. time:     2.8935621821e+01
#  KMCLib: 50000 steps executed. time:     7.5117399973e+01
#  KMCLib: 52311 steps executed. time:     2.2751203642e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.6264345344e+00
#  KMCLib: 20000 steps executed. time:     5.8533081690e+00
#  KMCLib: 30000 steps executed. time:     1.3624782174e+01
#  KMCLib: 40000 steps executed. time:     2.7889958431e+01
#  KMCLib: 50000 steps executed. time:     7.0905292398e+01
#  KMCLib: 53871 steps executed. time:     1.9141027000e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.5560558260e+00
#  KMCLib: 20000 steps executed. time:     5.1366663947e+00
#  KMCLib: 30000 steps executed. time:     1.1864745260e+01
#  KMCLib: 40000 steps executed. time:     2.2118810934e+01
#  KMCLib: 50000 steps executed. time:     3.6806229193e+01
#  KMCLib: 60000 steps executed. time:     6.3863002211e+01
#  KMCLib: 70000 steps executed. time:     1.6657522118e+02
#  KMCLib: 71056 steps executed. time:     2.7450442135e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.4954295170e+00
#  KMCLib: 20000 steps executed. time:     4.8209229011e+00
#  KMCLib: 30000 steps executed. time:     1.0338579357e+01
#  KMCLib: 40000 steps executed. time:     1.9640202320e+01
#  KMCLib: 50000 steps executed. time:     3.3589353639e+01
#  KMCLib: 60000 steps executed. time:     5.8339513516e+01
#  KMCLib: 70000 steps executed. time:     1.4458698243e+02
#  KMCLib: 70931 steps executed. time:     2.0746540540e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.4527584196e+00
#  KMCLib: 20000 steps executed. time:     4.4383029789e+00
#  KMCLib: 30000 steps executed. time:     9.2819886592e+00
#  KMCLib: 40000 steps executed. time:     1.6145731120e+01
#  KMCLib: 50000 steps executed. time:     2.5687075220e+01
#  KMCLib: 60000 steps executed. time:     3.8243682054e+01
#  KMCLib: 70000 steps executed. time:     5.6143251307e+01
#  KMCLib: 80000 steps executed. time:     9.4173273979e+01
#  KMCLib: 88746 steps executed. time:     3.4421518779e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.3873439354e+00
#  KMCLib: 20000 steps executed. time:     4.1105364716e+00
#  KMCLib: 30000 steps executed. time:     8.6348103292e+00
#  KMCLib: 40000 steps executed. time:     1.4758910774e+01
#  KMCLib: 50000 steps executed. time:     2.2933128450e+01
#  KMCLib: 60000 steps executed. time:     3.3796876150e+01
#  KMCLib: 70000 steps executed. time:     4.8695133929e+01
#  KMCLib: 80000 steps executed. time:     6.9471261223e+01
#  KMCLib: 90000 steps executed. time:     1.0225538948e+02
#  KMCLib: 99701 steps executed. time:     2.4007966091e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.3495459096e+00
#  KMCLib: 20000 steps executed. time:     3.7816552504e+00
#  KMCLib: 30000 steps executed. time:     7.5687117026e+00
#  KMCLib: 40000 steps executed. time:     1.2959444737e+01
#  KMCLib: 50000 steps executed. time:     2.0004680323e+01
#  KMCLib: 60000 steps executed. time:     2.8924462711e+01
#  KMCLib: 70000 steps executed. time:     4.0351126846e+01
#  KMCLib: 80000 steps executed. time:     5.5195253096e+01
#  KMCLib: 90000 steps executed. time:     7.5716725198e+01
#  KMCLib: 100000 steps executed. time:     1.0515748393e+02
#  KMCLib: 110000 steps executed. time:     1.4156412534e+02
#  KMCLib: 120000 steps executed. time:     1.8753088114e+02
#  KMCLib: 130000 steps executed. time:     3.0190656792e+02
#  KMCLib: 140000 steps executed. time:     5.3889059715e+02
#  KMCLib: 141266 steps executed. time:     6.4960136243e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.3048222472e+00
#  KMCLib: 20000 steps executed. time:     3.6601213571e+00
#  KMCLib: 30000 steps executed. time:     7.3667535547e+00
#  KMCLib: 40000 steps executed. time:     1.2090279717e+01
#  KMCLib: 50000 steps executed. time:     1.8293801860e+01
#  KMCLib: 60000 steps executed. time:     2.5388799863e+01
#  KMCLib: 70000 steps executed. time:     3.3216613221e+01
#  KMCLib: 80000 steps executed. time:     4.2520269659e+01
#  KMCLib: 90000 steps executed. time:     5.3176067897e+01
#  KMCLib: 100000 steps executed. time:     6.6097471166e+01
#  KMCLib: 110000 steps executed. time:     8.0072945131e+01
#  KMCLib: 120000 steps executed. time:     9.5346301781e+01
#  KMCLib: 130000 steps executed. time:     1.1561780044e+02
#  KMCLib: 140000 steps executed. time:     1.4253790062e+02
#  KMCLib: 150000 steps executed. time:     1.8149509091e+02
#  KMCLib: 160000 steps executed. time:     2.4480130438e+02
#  KMCLib: 170000 steps executed. time:     3.2473545847e+02
#  KMCLib: 180000 steps executed. time:     5.1143778357e+02
#  KMCLib: 183796 steps executed. time:     7.3934344317e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.3077217526e+00
#  KMCLib: 20000 steps executed. time:     3.3844560207e+00
#  KMCLib: 30000 steps executed. time:     6.6153883099e+00
#  KMCLib: 40000 steps executed. time:     1.0883840983e+01
#  KMCLib: 50000 steps executed. time:     1.6203352617e+01
#  KMCLib: 60000 steps executed. time:     2.2357591215e+01
#  KMCLib: 70000 steps executed. time:     3.0059403634e+01
#  KMCLib: 80000 steps executed. time:     3.8501799311e+01
#  KMCLib: 90000 steps executed. time:     4.7923749261e+01
#  KMCLib: 100000 steps executed. time:     5.8209906269e+01
#  KMCLib: 110000 steps executed. time:     6.9982308413e+01
#  KMCLib: 120000 steps executed. time:     8.3483741772e+01
#  KMCLib: 130000 steps executed. time:     9.9208813897e+01
#  KMCLib: 140000 steps executed. time:     1.1558076190e+02
#  KMCLib: 150000 steps executed. time:     1.3388815051e+02
#  KMCLib: 160000 steps executed. time:     1.5151391389e+02
#  KMCLib: 170000 steps executed. time:     1.6936506705e+02
#  KMCLib: 180000 steps executed. time:     1.8756443573e+02
#  KMCLib: 190000 steps executed. time:     2.0771109809e+02
#  KMCLib: 200000 steps executed. time:     2.2731464927e+02
#  KMCLib: 210000 steps executed. time:     2.5198174399e+02
#  KMCLib: 220000 steps executed. time:     2.7994672209e+02
#  KMCLib: 230000 steps executed. time:     3.1177714971e+02
#  KMCLib: 240000 steps executed. time:     3.5046192252e+02
#  KMCLib: 250000 steps executed. time:     3.8251300757e+02
#  KMCLib: 260000 steps executed. time:     4.1415643926e+02
#  KMCLib: 270000 steps executed. time:     4.3885820529e+02
#  KMCLib: 280000 steps executed. time:     4.6880770236e+02
#  KMCLib: 290000 steps executed. time:     4.9912111672e+02
#  KMCLib: 300000 steps executed. time:     5.2864767074e+02
#  KMCLib: 310000 steps executed. time:     5.6090801748e+02
#  KMCLib: 320000 steps executed. time:     5.9938980052e+02
#  KMCLib: 330000 steps executed. time:     6.3511249052e+02
#  KMCLib: 340000 steps executed. time:     6.7165865979e+02
#  KMCLib: 350000 steps executed. time:     7.2006644364e+02
#  KMCLib: 360000 steps executed. time:     7.6129714371e+02
#  KMCLib: 370000 steps executed. time:     7.9925688356e+02
#  KMCLib: 380000 steps executed. time:     8.4135436689e+02
#  KMCLib: 390000 steps executed. time:     8.8545992293e+02
#  KMCLib: 400000 steps executed. time:     9.3938111606e+02
#  KMCLib: 410000 steps executed. time:     9.9917735421e+02
#  KMCLib: 420000 steps executed. time:     1.0596383597e+03
#  KMCLib: 430000 steps executed. time:     1.1334911603e+03
#  KMCLib: 440000 steps executed. time:     1.2040870804e+03
#  KMCLib: 450000 steps executed. time:     1.2698984231e+03
#  KMCLib: 460000 steps executed. time:     1.3896757962e+03
#  KMCLib: 470000 steps executed. time:     1.5531185209e+03
#  KMCLib: 474846 steps executed. time:     1.6964653720e+03
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.2636947155e+00
#  KMCLib: 20000 steps executed. time:     3.3374988676e+00
#  KMCLib: 30000 steps executed. time:     6.3352263364e+00
#  KMCLib: 40000 steps executed. time:     1.0051210095e+01
#  KMCLib: 50000 steps executed. time:     1.4921042509e+01
#  KMCLib: 60000 steps executed. time:     2.0434389377e+01
#  KMCLib: 70000 steps executed. time:     2.6917237796e+01
#  KMCLib: 80000 steps executed. time:     3.4087108740e+01
#  KMCLib: 90000 steps executed. time:     4.1695209751e+01
#  KMCLib: 100000 steps executed. time:     4.9359969384e+01
#  KMCLib: 110000 steps executed. time:     5.7557948438e+01
#  KMCLib: 120000 steps executed. time:     6.6063264333e+01
#  KMCLib: 130000 steps executed. time:     7.4574843102e+01
#  KMCLib: 140000 steps executed. time:     8.2797070870e+01
#  KMCLib: 150000 steps executed. time:     9.1875051812e+01
#  KMCLib: 160000 steps executed. time:     1.0059941417e+02
#  KMCLib: 170000 steps executed. time:     1.0972053016e+02
#  KMCLib: 180000 steps executed. time:     1.2037377430e+02
#  KMCLib: 190000 steps executed. time:     1.3106707386e+02
#  KMCLib: 200000 steps executed. time:     1.4136754008e+02
#  KMCLib: 210000 steps executed. time:     1.5370061979e+02
#  KMCLib: 220000 steps executed. time:     1.6630254933e+02
#  KMCLib: 230000 steps executed. time:     1.7851641294e+02
#  KMCLib: 240000 steps executed. time:     1.9187514755e+02
#  KMCLib: 250000 steps executed. time:     2.0440828024e+02
#  KMCLib: 260000 steps executed. time:     2.1729092714e+02
#  KMCLib: 270000 steps executed. time:     2.3119973519e+02
#  KMCLib: 280000 steps executed. time:     2.4701033161e+02
#  KMCLib: 290000 steps executed. time:     2.6208533804e+02
#  KMCLib: 300000 steps executed. time:     2.7624982983e+02
#  KMCLib: 310000 steps executed. time:     2.9078941164e+02
#  KMCLib: 320000 steps executed. time:     3.0726038652e+02
#  KMCLib: 330000 steps executed. time:     3.2474298479e+02
#  KMCLib: 340000 steps executed. time:     3.4154198770e+02
#  KMCLib: 350000 steps executed. time:     3.5894504427e+02
#  KMCLib: 360000 steps executed. time:     3.7617479550e+02
#  KMCLib: 370000 steps executed. time:     3.9130211732e+02
#  KMCLib: 380000 steps executed. time:     4.0849178090e+02
#  KMCLib: 390000 steps executed. time:     4.2716837234e+02
#  KMCLib: 400000 steps executed. time:     4.4549987651e+02
#  KMCLib: 410000 steps executed. time:     4.6448726914e+02
#  KMCLib: 420000 steps executed. time:     4.8605477031e+02
#  KMCLib: 430000 steps executed. time:     5.0540760491e+02
#  KMCLib: 440000 steps executed. time:     5.2336064979e+02
#  KMCLib: 450000 steps executed. time:     5.3976616793e+02
#  KMCLib: 460000 steps executed. time:     5.5680199884e+02
#  KMCLib: 470000 steps executed. time:     5.7395490362e+02
#  KMCLib: 480000 steps executed. time:     5.9045836372e+02
#  KMCLib: 490000 steps executed. time:     6.0842329664e+02
#  KMCLib: 500000 steps executed. time:     6.2832604730e+02
#  KMCLib: 510000 steps executed. time:     6.4602543216e+02
#  KMCLib: 520000 steps executed. time:     6.6261129238e+02
#  KMCLib: 530000 steps executed. time:     6.7814830464e+02
#  KMCLib: 540000 steps executed. time:     6.9527389374e+02
#  KMCLib: 550000 steps executed. time:     7.1302500562e+02
#  KMCLib: 560000 steps executed. time:     7.3119851915e+02
#  KMCLib: 570000 steps executed. time:     7.4833664021e+02
#  KMCLib: 580000 steps executed. time:     7.6466692261e+02
#  KMCLib: 590000 steps executed. time:     7.8116245197e+02
#  KMCLib: 600000 steps executed. time:     7.9886053276e+02
#  KMCLib: 610000 steps executed. time:     8.1733809524e+02
#  KMCLib: 620000 steps executed. time:     8.3622638122e+02
#  KMCLib: 630000 steps executed. time:     8.5727779962e+02
#  KMCLib: 640000 steps executed. time:     8.7601049128e+02
#  KMCLib: 650000 steps executed. time:     8.9159195489e+02
#  KMCLib: 660000 steps executed. time:     9.0894734367e+02
#  KMCLib: 670000 steps executed. time:     9.2675767374e+02
#  KMCLib: 680000 steps executed. time:     9.4453683381e+02
#  KMCLib: 690000 steps executed. time:     9.6355144490e+02
#  KMCLib: 700000 steps executed. time:     9.8274620544e+02
#  KMCLib: 710000 steps executed. time:     1.0009053781e+03
#  KMCLib: 720000 steps executed. time:     1.0204995399e+03
#  KMCLib: 730000 steps executed. time:     1.0406336670e+03
#  KMCLib: 740000 steps executed. time:     1.0585684390e+03
#  KMCLib: 750000 steps executed. time:     1.0753639517e+03
#  KMCLib: 760000 steps executed. time:     1.0918869873e+03
#  KMCLib: 770000 steps executed. time:     1.1078771918e+03
#  KMCLib: 780000 steps executed. time:     1.1231386739e+03
#  KMCLib: 790000 steps executed. time:     1.1381476124e+03
#  KMCLib: 800000 steps executed. time:     1.1525706109e+03
#  KMCLib: 810000 steps executed. time:     1.1682078608e+03
#  KMCLib: 820000 steps executed. time:     1.1823014862e+03
#  KMCLib: 830000 steps executed. time:     1.1963370639e+03
#  KMCLib: 840000 steps executed. time:     1.2111419104e+03
#  KMCLib: 850000 steps executed. time:     1.2261933240e+03
#  KMCLib: 860000 steps executed. time:     1.2441997032e+03
#  KMCLib: 870000 steps executed. time:     1.2617417628e+03
#  KMCLib: 880000 steps executed. time:     1.2794231719e+03
#  KMCLib: 890000 steps executed. time:     1.2975220597e+03
#  KMCLib: 900000 steps executed. time:     1.3142662373e+03
#  KMCLib: 910000 steps executed. time:     1.3307823534e+03
#  KMCLib: 920000 steps executed. time:     1.3477545462e+03
#  KMCLib: 930000 steps executed. time:     1.3680818828e+03
#  KMCLib: 940000 steps executed. time:     1.3870894110e+03
#  KMCLib: 950000 steps executed. time:     1.4076696598e+03
#  KMCLib: 960000 steps executed. time:     1.4309385717e+03
#  KMCLib: 970000 steps executed. time:     1.4517518285e+03
#  KMCLib: 980000 steps executed. time:     1.4743729150e+03
#  KMCLib: 990000 steps executed. time:     1.4955678144e+03
#  KMCLib: 1000000 steps executed. time:     1.5168272514e+03
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.2201477072e+00
#  KMCLib: 20000 steps executed. time:     3.1023803876e+00
#  KMCLib: 30000 steps executed. time:     5.8208336323e+00
#  KMCLib: 40000 steps executed. time:     9.2280185920e+00
#  KMCLib: 50000 steps executed. time:     1.3078468359e+01
#  KMCLib: 60000 steps executed. time:     1.7440071219e+01
#  KMCLib: 70000 steps executed. time:     2.2267920675e+01
#  KMCLib: 80000 steps executed. time:     2.7630210976e+01
#  KMCLib: 90000 steps executed. time:     3.3239737335e+01
#  KMCLib: 100000 steps executed. time:     3.9072952938e+01
#  KMCLib: 110000 steps executed. time:     4.5196514838e+01
#  KMCLib: 120000 steps executed. time:     5.1947177572e+01
#  KMCLib: 130000 steps executed. time:     5.9058273794e+01
#  KMCLib: 140000 steps executed. time:     6.6192354694e+01
#  KMCLib: 150000 steps executed. time:     7.3555817268e+01
#  KMCLib: 160000 steps executed. time:     8.1144377453e+01
#  KMCLib: 170000 steps executed. time:     8.9054074723e+01
#  KMCLib: 180000 steps executed. time:     9.7158057233e+01
#  KMCLib: 190000 steps executed. time:     1.0557690174e+02
#  KMCLib: 200000 steps executed. time:     1.1448744307e+02
#  KMCLib: 210000 steps executed. time:     1.2348712569e+02
#  KMCLib: 220000 steps executed. time:     1.3249103078e+02
#  KMCLib: 230000 steps executed. time:     1.4169838556e+02
#  KMCLib: 240000 steps executed. time:     1.5093928051e+02
#  KMCLib: 250000 steps executed. time:     1.6144047290e+02
#  KMCLib: 260000 steps executed. time:     1.7152398509e+02
#  KMCLib: 270000 steps executed. time:     1.8087498291e+02
#  KMCLib: 280000 steps executed. time:     1.9129485504e+02
#  KMCLib: 290000 steps executed. time:     2.0120216577e+02
#  KMCLib: 300000 steps executed. time:     2.1021103827e+02
#  KMCLib: 310000 steps executed. time:     2.1926110726e+02
#  KMCLib: 320000 steps executed. time:     2.2822329819e+02
#  KMCLib: 330000 steps executed. time:     2.3702163647e+02
#  KMCLib: 340000 steps executed. time:     2.4610001577e+02
#  KMCLib: 350000 steps executed. time:     2.5578571807e+02
#  KMCLib: 360000 steps executed. time:     2.6580790785e+02
#  KMCLib: 370000 steps executed. time:     2.7628768083e+02
#  KMCLib: 380000 steps executed. time:     2.8646661768e+02
#  KMCLib: 390000 steps executed. time:     2.9612136180e+02
#  KMCLib: 400000 steps executed. time:     3.0607448023e+02
#  KMCLib: 410000 steps executed. time:     3.1581411460e+02
#  KMCLib: 420000 steps executed. time:     3.2612814721e+02
#  KMCLib: 430000 steps executed. time:     3.3618151425e+02
#  KMCLib: 440000 steps executed. time:     3.4667576797e+02
#  KMCLib: 450000 steps executed. time:     3.5659571308e+02
#  KMCLib: 460000 steps executed. time:     3.6716349695e+02
#  KMCLib: 470000 steps executed. time:     3.7682166095e+02
#  KMCLib: 480000 steps executed. time:     3.8713037168e+02
#  KMCLib: 490000 steps executed. time:     3.9870859570e+02
#  KMCLib: 500000 steps executed. time:     4.0936181352e+02
#  KMCLib: 510000 steps executed. time:     4.1986640070e+02
#  KMCLib: 520000 steps executed. time:     4.3003336258e+02
#  KMCLib: 530000 steps executed. time:     4.3973976647e+02
#  KMCLib: 540000 steps executed. time:     4.4963647760e+02
#  KMCLib: 550000 steps executed. time:     4.6014728728e+02
#  KMCLib: 560000 steps executed. time:     4.7073441969e+02
#  KMCLib: 570000 steps executed. time:     4.8073787195e+02
#  KMCLib: 580000 steps executed. time:     4.9087687188e+02
#  KMCLib: 590000 steps executed. time:     5.0094945952e+02
#  KMCLib: 600000 steps executed. time:     5.1128839884e+02
#  KMCLib: 610000 steps executed. time:     5.2153013301e+02
#  KMCLib: 620000 steps executed. time:     5.3211742211e+02
#  KMCLib: 630000 steps executed. time:     5.4265334893e+02
#  KMCLib: 640000 steps executed. time:     5.5318598499e+02
#  KMCLib: 650000 steps executed. time:     5.6353090444e+02
#  KMCLib: 660000 steps executed. time:     5.7301185666e+02
#  KMCLib: 670000 steps executed. time:     5.8256547798e+02
#  KMCLib: 680000 steps executed. time:     5.9225893948e+02
#  KMCLib: 690000 steps executed. time:     6.0164349769e+02
#  KMCLib: 700000 steps executed. time:     6.1084629091e+02
#  KMCLib: 710000 steps executed. time:     6.2016494773e+02
#  KMCLib: 720000 steps executed. time:     6.2965676117e+02
#  KMCLib: 730000 steps executed. time:     6.3866416049e+02
#  KMCLib: 740000 steps executed. time:     6.4786486538e+02
#  KMCLib: 750000 steps executed. time:     6.5704166092e+02
#  KMCLib: 760000 steps executed. time:     6.6627947664e+02
#  KMCLib: 770000 steps executed. time:     6.7578100155e+02
#  KMCLib: 780000 steps executed. time:     6.8533550590e+02
#  KMCLib: 790000 steps executed. time:     6.9454762274e+02
#  KMCLib: 800000 steps executed. time:     7.0322979962e+02
#  KMCLib: 810000 steps executed. time:     7.1244984662e+02
#  KMCLib: 820000 steps executed. time:     7.2262024162e+02
#  KMCLib: 830000 steps executed. time:     7.3307726411e+02
#  KMCLib: 840000 steps executed. time:     7.4469236228e+02
#  KMCLib: 850000 steps executed. time:     7.5573211109e+02
#  KMCLib: 860000 steps executed. time:     7.6641845334e+02
#  KMCLib: 870000 steps executed. time:     7.7683810296e+02
#  KMCLib: 880000 steps executed. time:     7.8709670637e+02
#  KMCLib: 890000 steps executed. time:     7.9825018105e+02
#  KMCLib: 900000 steps executed. time:     8.1010555692e+02
#  KMCLib: 910000 steps executed. time:     8.2193033774e+02
#  KMCLib: 920000 steps executed. time:     8.3347740253e+02
#  KMCLib: 930000 steps executed. time:     8.4522302488e+02
#  KMCLib: 940000 steps executed. time:     8.5556308571e+02
#  KMCLib: 950000 steps executed. time:     8.6562873652e+02
#  KMCLib: 960000 steps executed. time:     8.7625656597e+02
#  KMCLib: 970000 steps executed. time:     8.8676175082e+02
#  KMCLib: 980000 steps executed. time:     8.9653824504e+02
#  KMCLib: 990000 steps executed. time:     9.0622110061e+02
#  KMCLib: 1000000 steps executed. time:     9.1570508673e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.2113619101e+00
#  KMCLib: 20000 steps executed. time:     2.9753887450e+00
#  KMCLib: 30000 steps executed. time:     5.3799368890e+00
#  KMCLib: 40000 steps executed. time:     8.3668380808e+00
#  KMCLib: 50000 steps executed. time:     1.1684669208e+01
#  KMCLib: 60000 steps executed. time:     1.5548939416e+01
#  KMCLib: 70000 steps executed. time:     1.9979357812e+01
#  KMCLib: 80000 steps executed. time:     2.4549125309e+01
#  KMCLib: 90000 steps executed. time:     2.9725781473e+01
#  KMCLib: 100000 steps executed. time:     3.5263608588e+01
#  KMCLib: 110000 steps executed. time:     4.1396622001e+01
#  KMCLib: 120000 steps executed. time:     4.7469748621e+01
#  KMCLib: 130000 steps executed. time:     5.3674636306e+01
#  KMCLib: 140000 steps executed. time:     6.0205033168e+01
#  KMCLib: 150000 steps executed. time:     6.6659155000e+01
#  KMCLib: 160000 steps executed. time:     7.3073132664e+01
#  KMCLib: 170000 steps executed. time:     7.9456141496e+01
#  KMCLib: 180000 steps executed. time:     8.5781932579e+01
#  KMCLib: 190000 steps executed. time:     9.2302293472e+01
#  KMCLib: 200000 steps executed. time:     9.9061516768e+01
#  KMCLib: 210000 steps executed. time:     1.0573752496e+02
#  KMCLib: 220000 steps executed. time:     1.1254122426e+02
#  KMCLib: 230000 steps executed. time:     1.1961765035e+02
#  KMCLib: 240000 steps executed. time:     1.2616091964e+02
#  KMCLib: 250000 steps executed. time:     1.3244530048e+02
#  KMCLib: 260000 steps executed. time:     1.3909024541e+02
#  KMCLib: 270000 steps executed. time:     1.4593910856e+02
#  KMCLib: 280000 steps executed. time:     1.5264540013e+02
#  KMCLib: 290000 steps executed. time:     1.5944267431e+02
#  KMCLib: 300000 steps executed. time:     1.6671936438e+02
#  KMCLib: 310000 steps executed. time:     1.7378973502e+02
#  KMCLib: 320000 steps executed. time:     1.8049555738e+02
#  KMCLib: 330000 steps executed. time:     1.8717705174e+02
#  KMCLib: 340000 steps executed. time:     1.9408968389e+02
#  KMCLib: 350000 steps executed. time:     2.0083435343e+02
#  KMCLib: 360000 steps executed. time:     2.0768098401e+02
#  KMCLib: 370000 steps executed. time:     2.1451214696e+02
#  KMCLib: 380000 steps executed. time:     2.2150742611e+02
#  KMCLib: 390000 steps executed. time:     2.2837989611e+02
#  KMCLib: 400000 steps executed. time:     2.3503739807e+02
#  KMCLib: 410000 steps executed. time:     2.4150948633e+02
#  KMCLib: 420000 steps executed. time:     2.4797940132e+02
#  KMCLib: 430000 steps executed. time:     2.5408327884e+02
#  KMCLib: 440000 steps executed. time:     2.6112914469e+02
#  KMCLib: 450000 steps executed. time:     2.6819382851e+02
#  KMCLib: 460000 steps executed. time:     2.7527918483e+02
#  KMCLib: 470000 steps executed. time:     2.8243745846e+02
#  KMCLib: 480000 steps executed. time:     2.8980076804e+02
#  KMCLib: 490000 steps executed. time:     2.9731550451e+02
#  KMCLib: 500000 steps executed. time:     3.0439911772e+02
#  KMCLib: 510000 steps executed. time:     3.1165794553e+02
#  KMCLib: 520000 steps executed. time:     3.1933568147e+02
#  KMCLib: 530000 steps executed. time:     3.2643478441e+02
#  KMCLib: 540000 steps executed. time:     3.3383390126e+02
#  KMCLib: 550000 steps executed. time:     3.4100265323e+02
#  KMCLib: 560000 steps executed. time:     3.4798067893e+02
#  KMCLib: 570000 steps executed. time:     3.5547740898e+02
#  KMCLib: 580000 steps executed. time:     3.6276681222e+02
#  KMCLib: 590000 steps executed. time:     3.6952405921e+02
#  KMCLib: 600000 steps executed. time:     3.7668237306e+02
#  KMCLib: 610000 steps executed. time:     3.8360185537e+02
#  KMCLib: 620000 steps executed. time:     3.9075596918e+02
#  KMCLib: 630000 steps executed. time:     3.9745008821e+02
#  KMCLib: 640000 steps executed. time:     4.0402630895e+02
#  KMCLib: 650000 steps executed. time:     4.1093661417e+02
#  KMCLib: 660000 steps executed. time:     4.1775930353e+02
#  KMCLib: 670000 steps executed. time:     4.2471872118e+02
#  KMCLib: 680000 steps executed. time:     4.3179726132e+02
#  KMCLib: 690000 steps executed. time:     4.3858263840e+02
#  KMCLib: 700000 steps executed. time:     4.4570450086e+02
#  KMCLib: 710000 steps executed. time:     4.5296730469e+02
#  KMCLib: 720000 steps executed. time:     4.6030609429e+02
#  KMCLib: 730000 steps executed. time:     4.6715835813e+02
#  KMCLib: 740000 steps executed. time:     4.7379441082e+02
#  KMCLib: 750000 steps executed. time:     4.8028551104e+02
#  KMCLib: 760000 steps executed. time:     4.8670090067e+02
#  KMCLib: 770000 steps executed. time:     4.9342743385e+02
#  KMCLib: 780000 steps executed. time:     4.9983478783e+02
#  KMCLib: 790000 steps executed. time:     5.0634054524e+02
#  KMCLib: 800000 steps executed. time:     5.1297493889e+02
#  KMCLib: 810000 steps executed. time:     5.1974618728e+02
#  KMCLib: 820000 steps executed. time:     5.2638367531e+02
#  KMCLib: 830000 steps executed. time:     5.3349989357e+02
#  KMCLib: 840000 steps executed. time:     5.4099826504e+02
#  KMCLib: 850000 steps executed. time:     5.4831928433e+02
#  KMCLib: 860000 steps executed. time:     5.5559361815e+02
#  KMCLib: 870000 steps executed. time:     5.6303784370e+02
#  KMCLib: 880000 steps executed. time:     5.7000987799e+02
#  KMCLib: 890000 steps executed. time:     5.7676465526e+02
#  KMCLib: 900000 steps executed. time:     5.8354830136e+02
#  KMCLib: 910000 steps executed. time:     5.9068671950e+02
#  KMCLib: 920000 steps executed. time:     5.9813935379e+02
#  KMCLib: 930000 steps executed. time:     6.0549027743e+02
#  KMCLib: 940000 steps executed. time:     6.1261004782e+02
#  KMCLib: 950000 steps executed. time:     6.1959037247e+02
#  KMCLib: 960000 steps executed. time:     6.2682192571e+02
#  KMCLib: 970000 steps executed. time:     6.3426739293e+02
#  KMCLib: 980000 steps executed. time:     6.4138022844e+02
#  KMCLib: 990000 steps executed. time:     6.4831773377e+02
#  KMCLib: 1000000 steps executed. time:     6.5540323119e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.2132265307e+00
#  KMCLib: 20000 steps executed. time:     2.8895815630e+00
#  KMCLib: 30000 steps executed. time:     5.0966398641e+00
#  KMCLib: 40000 steps executed. time:     7.8184011415e+00
#  KMCLib: 50000 steps executed. time:     1.1037321625e+01
#  KMCLib: 60000 steps executed. time:     1.4485993425e+01
#  KMCLib: 70000 steps executed. time:     1.8238985525e+01
#  KMCLib: 80000 steps executed. time:     2.2148805180e+01
#  KMCLib: 90000 steps executed. time:     2.6214221827e+01
#  KMCLib: 100000 steps executed. time:     3.0645807539e+01
#  KMCLib: 110000 steps executed. time:     3.5373749660e+01
#  KMCLib: 120000 steps executed. time:     3.9891055545e+01
#  KMCLib: 130000 steps executed. time:     4.4461106425e+01
#  KMCLib: 140000 steps executed. time:     4.9276055280e+01
#  KMCLib: 150000 steps executed. time:     5.4207728946e+01
#  KMCLib: 160000 steps executed. time:     5.9366585093e+01
#  KMCLib: 170000 steps executed. time:     6.4754830329e+01
#  KMCLib: 180000 steps executed. time:     6.9926732956e+01
#  KMCLib: 190000 steps executed. time:     7.4984673609e+01
#  KMCLib: 200000 steps executed. time:     8.0274040921e+01
#  KMCLib: 210000 steps executed. time:     8.5898886069e+01
#  KMCLib: 220000 steps executed. time:     9.1438702782e+01
#  KMCLib: 230000 steps executed. time:     9.6837401850e+01
#  KMCLib: 240000 steps executed. time:     1.0197581680e+02
#  KMCLib: 250000 steps executed. time:     1.0735989126e+02
#  KMCLib: 260000 steps executed. time:     1.1274887898e+02
#  KMCLib: 270000 steps executed. time:     1.1795397252e+02
#  KMCLib: 280000 steps executed. time:     1.2313755456e+02
#  KMCLib: 290000 steps executed. time:     1.2829867749e+02
#  KMCLib: 300000 steps executed. time:     1.3319851955e+02
#  KMCLib: 310000 steps executed. time:     1.3829691347e+02
#  KMCLib: 320000 steps executed. time:     1.4341715558e+02
#  KMCLib: 330000 steps executed. time:     1.4846124883e+02
#  KMCLib: 340000 steps executed. time:     1.5367306738e+02
#  KMCLib: 350000 steps executed. time:     1.5870946753e+02
#  KMCLib: 360000 steps executed. time:     1.6377545780e+02
#  KMCLib: 370000 steps executed. time:     1.6882412865e+02
#  KMCLib: 380000 steps executed. time:     1.7415802451e+02
#  KMCLib: 390000 steps executed. time:     1.7964077826e+02
#  KMCLib: 400000 steps executed. time:     1.8513249820e+02
#  KMCLib: 410000 steps executed. time:     1.9053167404e+02
#  KMCLib: 420000 steps executed. time:     1.9613236181e+02
#  KMCLib: 430000 steps executed. time:     2.0160908059e+02
#  KMCLib: 440000 steps executed. time:     2.0729413100e+02
#  KMCLib: 450000 steps executed. time:     2.1302968660e+02
#  KMCLib: 460000 steps executed. time:     2.1845262278e+02
#  KMCLib: 470000 steps executed. time:     2.2385328029e+02
#  KMCLib: 480000 steps executed. time:     2.2923847338e+02
#  KMCLib: 490000 steps executed. time:     2.3468050318e+02
#  KMCLib: 500000 steps executed. time:     2.4013402671e+02
#  KMCLib: 510000 steps executed. time:     2.4567028534e+02
#  KMCLib: 520000 steps executed. time:     2.5108817768e+02
#  KMCLib: 530000 steps executed. time:     2.5659667691e+02
#  KMCLib: 540000 steps executed. time:     2.6189218960e+02
#  KMCLib: 550000 steps executed. time:     2.6702078689e+02
#  KMCLib: 560000 steps executed. time:     2.7216337807e+02
#  KMCLib: 570000 steps executed. time:     2.7739323726e+02
#  KMCLib: 580000 steps executed. time:     2.8244985547e+02
#  KMCLib: 590000 steps executed. time:     2.8775345117e+02
#  KMCLib: 600000 steps executed. time:     2.9314652462e+02
#  KMCLib: 610000 steps executed. time:     2.9857456228e+02
#  KMCLib: 620000 steps executed. time:     3.0405903153e+02
#  KMCLib: 630000 steps executed. time:     3.0997306783e+02
#  KMCLib: 640000 steps executed. time:     3.1591898149e+02
#  KMCLib: 650000 steps executed. time:     3.2152708929e+02
#  KMCLib: 660000 steps executed. time:     3.2731214115e+02
#  KMCLib: 670000 steps executed. time:     3.3287208869e+02
#  KMCLib: 680000 steps executed. time:     3.3815268400e+02
#  KMCLib: 690000 steps executed. time:     3.4339013419e+02
#  KMCLib: 700000 steps executed. time:     3.4875996535e+02
#  KMCLib: 710000 steps executed. time:     3.5402367471e+02
#  KMCLib: 720000 steps executed. time:     3.5928056554e+02
#  KMCLib: 730000 steps executed. time:     3.6463253501e+02
#  KMCLib: 740000 steps executed. time:     3.7015503799e+02
#  KMCLib: 750000 steps executed. time:     3.7554162380e+02
#  KMCLib: 760000 steps executed. time:     3.8124517041e+02
#  KMCLib: 770000 steps executed. time:     3.8736482590e+02
#  KMCLib: 780000 steps executed. time:     3.9369670486e+02
#  KMCLib: 790000 steps executed. time:     4.0011228075e+02
#  KMCLib: 800000 steps executed. time:     4.0626429346e+02
#  KMCLib: 810000 steps executed. time:     4.1259850722e+02
#  KMCLib: 820000 steps executed. time:     4.1845053466e+02
#  KMCLib: 830000 steps executed. time:     4.2450967319e+02
#  KMCLib: 840000 steps executed. time:     4.3041404710e+02
#  KMCLib: 850000 steps executed. time:     4.3616879860e+02
#  KMCLib: 860000 steps executed. time:     4.4203902097e+02
#  KMCLib: 870000 steps executed. time:     4.4774817187e+02
#  KMCLib: 880000 steps executed. time:     4.5350572362e+02
#  KMCLib: 890000 steps executed. time:     4.5916371017e+02
#  KMCLib: 900000 steps executed. time:     4.6453108677e+02
#  KMCLib: 910000 steps executed. time:     4.6976640230e+02
#  KMCLib: 920000 steps executed. time:     4.7507261320e+02
#  KMCLib: 930000 steps executed. time:     4.8077779252e+02
#  KMCLib: 940000 steps executed. time:     4.8641278879e+02
#  KMCLib: 950000 steps executed. time:     4.9178042823e+02
#  KMCLib: 960000 steps executed. time:     4.9702671498e+02
#  KMCLib: 970000 steps executed. time:     5.0245340480e+02
#  KMCLib: 980000 steps executed. time:     5.0793851125e+02
#  KMCLib: 990000 steps executed. time:     5.1310518845e+02
#  KMCLib: 1000000 steps executed. time:     5.1835248838e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.1822581219e+00
#  KMCLib: 20000 steps executed. time:     2.7781765413e+00
#  KMCLib: 30000 steps executed. time:     4.8384426486e+00
#  KMCLib: 40000 steps executed. time:     7.3018152895e+00
#  KMCLib: 50000 steps executed. time:     1.0276269382e+01
#  KMCLib: 60000 steps executed. time:     1.3494587591e+01
#  KMCLib: 70000 steps executed. time:     1.7115984794e+01
#  KMCLib: 80000 steps executed. time:     2.0867159650e+01
#  KMCLib: 90000 steps executed. time:     2.4750412046e+01
#  KMCLib: 100000 steps executed. time:     2.8783293808e+01
#  KMCLib: 110000 steps executed. time:     3.2978044226e+01
#  KMCLib: 120000 steps executed. time:     3.7194526202e+01
#  KMCLib: 130000 steps executed. time:     4.1441377707e+01
#  KMCLib: 140000 steps executed. time:     4.5680712942e+01
#  KMCLib: 150000 steps executed. time:     5.0198689545e+01
#  KMCLib: 160000 steps executed. time:     5.4724115151e+01
#  KMCLib: 170000 steps executed. time:     5.9231427932e+01
#  KMCLib: 180000 steps executed. time:     6.3666706913e+01
#  KMCLib: 190000 steps executed. time:     6.7991722354e+01
#  KMCLib: 200000 steps executed. time:     7.2111873813e+01
#  KMCLib: 210000 steps executed. time:     7.6312442669e+01
#  KMCLib: 220000 steps executed. time:     8.0596775506e+01
#  KMCLib: 230000 steps executed. time:     8.4824521261e+01
#  KMCLib: 240000 steps executed. time:     8.9160633951e+01
#  KMCLib: 250000 steps executed. time:     9.3570072839e+01
#  KMCLib: 260000 steps executed. time:     9.7949724038e+01
#  KMCLib: 270000 steps executed. time:     1.0242810579e+02
#  KMCLib: 280000 steps executed. time:     1.0691446557e+02
#  KMCLib: 290000 steps executed. time:     1.1153050232e+02
#  KMCLib: 300000 steps executed. time:     1.1624114140e+02
#  KMCLib: 310000 steps executed. time:     1.2096895056e+02
#  KMCLib: 320000 steps executed. time:     1.2554433631e+02
#  KMCLib: 330000 steps executed. time:     1.2997411655e+02
#  KMCLib: 340000 steps executed. time:     1.3465966420e+02
#  KMCLib: 350000 steps executed. time:     1.3922261902e+02
#  KMCLib: 360000 steps executed. time:     1.4393104646e+02
#  KMCLib: 370000 steps executed. time:     1.4859086239e+02
#  KMCLib: 380000 steps executed. time:     1.5318133869e+02
#  KMCLib: 390000 steps executed. time:     1.5777556235e+02
#  KMCLib: 400000 steps executed. time:     1.6232875814e+02
#  KMCLib: 410000 steps executed. time:     1.6687556502e+02
#  KMCLib: 420000 steps executed. time:     1.7152646146e+02
#  KMCLib: 430000 steps executed. time:     1.7600238437e+02
#  KMCLib: 440000 steps executed. time:     1.8040217531e+02
#  KMCLib: 450000 steps executed. time:     1.8510339583e+02
#  KMCLib: 460000 steps executed. time:     1.8974285293e+02
#  KMCLib: 470000 steps executed. time:     1.9426366106e+02
#  KMCLib: 480000 steps executed. time:     1.9885109718e+02
#  KMCLib: 490000 steps executed. time:     2.0340959169e+02
#  KMCLib: 500000 steps executed. time:     2.0799468479e+02
#  KMCLib: 510000 steps executed. time:     2.1261907100e+02
#  KMCLib: 520000 steps executed. time:     2.1701317646e+02
#  KMCLib: 530000 steps executed. time:     2.2135234889e+02
#  KMCLib: 540000 steps executed. time:     2.2579280445e+02
#  KMCLib: 550000 steps executed. time:     2.3034222872e+02
#  KMCLib: 560000 steps executed. time:     2.3494721661e+02
#  KMCLib: 570000 steps executed. time:     2.3961374232e+02
#  KMCLib: 580000 steps executed. time:     2.4434733447e+02
#  KMCLib: 590000 steps executed. time:     2.4929147314e+02
#  KMCLib: 600000 steps executed. time:     2.5418740292e+02
#  KMCLib: 610000 steps executed. time:     2.5909902162e+02
#  KMCLib: 620000 steps executed. time:     2.6378999831e+02
#  KMCLib: 630000 steps executed. time:     2.6856359279e+02
#  KMCLib: 640000 steps executed. time:     2.7363237815e+02
#  KMCLib: 650000 steps executed. time:     2.7869012614e+02
#  KMCLib: 660000 steps executed. time:     2.8355719475e+02
#  KMCLib: 670000 steps executed. time:     2.8855790739e+02
#  KMCLib: 680000 steps executed. time:     2.9345406319e+02
#  KMCLib: 690000 steps executed. time:     2.9800666798e+02
#  KMCLib: 700000 steps executed. time:     3.0267360006e+02
#  KMCLib: 710000 steps executed. time:     3.0749148911e+02
#  KMCLib: 720000 steps executed. time:     3.1242137589e+02
#  KMCLib: 730000 steps executed. time:     3.1740229034e+02
#  KMCLib: 740000 steps executed. time:     3.2214003591e+02
#  KMCLib: 750000 steps executed. time:     3.2697759632e+02
#  KMCLib: 760000 steps executed. time:     3.3162418805e+02
#  KMCLib: 770000 steps executed. time:     3.3632022405e+02
#  KMCLib: 780000 steps executed. time:     3.4119877744e+02
#  KMCLib: 790000 steps executed. time:     3.4612410121e+02
#  KMCLib: 800000 steps executed. time:     3.5094381330e+02
#  KMCLib: 810000 steps executed. time:     3.5606797039e+02
#  KMCLib: 820000 steps executed. time:     3.6132196834e+02
#  KMCLib: 830000 steps executed. time:     3.6649019254e+02
#  KMCLib: 840000 steps executed. time:     3.7150541685e+02
#  KMCLib: 850000 steps executed. time:     3.7683186826e+02
#  KMCLib: 860000 steps executed. time:     3.8167062308e+02
#  KMCLib: 870000 steps executed. time:     3.8643679746e+02
#  KMCLib: 880000 steps executed. time:     3.9115691274e+02
#  KMCLib: 890000 steps executed. time:     3.9615202973e+02
#  KMCLib: 900000 steps executed. time:     4.0086495620e+02
#  KMCLib: 910000 steps executed. time:     4.0542767038e+02
#  KMCLib: 920000 steps executed. time:     4.0992257030e+02
#  KMCLib: 930000 steps executed. time:     4.1466879158e+02
#  KMCLib: 940000 steps executed. time:     4.1910589047e+02
#  KMCLib: 950000 steps executed. time:     4.2353379596e+02
#  KMCLib: 960000 steps executed. time:     4.2780124183e+02
#  KMCLib: 970000 steps executed. time:     4.3215219592e+02
#  KMCLib: 980000 steps executed. time:     4.3676816631e+02
#  KMCLib: 990000 steps executed. time:     4.4170021472e+02
#  KMCLib: 1000000 steps executed. time:     4.4672366823e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.1519492969e+00
#  KMCLib: 20000 steps executed. time:     2.7256494176e+00
#  KMCLib: 30000 steps executed. time:     4.7544907408e+00
#  KMCLib: 40000 steps executed. time:     7.1904009478e+00
#  KMCLib: 50000 steps executed. time:     9.8471833846e+00
#  KMCLib: 60000 steps executed. time:     1.2715385556e+01
#  KMCLib: 70000 steps executed. time:     1.5901730290e+01
#  KMCLib: 80000 steps executed. time:     1.9148874511e+01
#  KMCLib: 90000 steps executed. time:     2.2565218138e+01
#  KMCLib: 100000 steps executed. time:     2.5997690684e+01
#  KMCLib: 110000 steps executed. time:     2.9544693222e+01
#  KMCLib: 120000 steps executed. time:     3.3112736348e+01
#  KMCLib: 130000 steps executed. time:     3.6539830921e+01
#  KMCLib: 140000 steps executed. time:     4.0196173098e+01
#  KMCLib: 150000 steps executed. time:     4.3900674528e+01
#  KMCLib: 160000 steps executed. time:     4.7507256476e+01
#  KMCLib: 170000 steps executed. time:     5.1199101432e+01
#  KMCLib: 180000 steps executed. time:     5.4817336161e+01
#  KMCLib: 190000 steps executed. time:     5.8439643654e+01
#  KMCLib: 200000 steps executed. time:     6.2275218315e+01
#  KMCLib: 210000 steps executed. time:     6.6067535833e+01
#  KMCLib: 220000 steps executed. time:     7.0022116979e+01
#  KMCLib: 230000 steps executed. time:     7.3932319699e+01
#  KMCLib: 240000 steps executed. time:     7.7869326654e+01
#  KMCLib: 250000 steps executed. time:     8.1931615076e+01
#  KMCLib: 260000 steps executed. time:     8.5975272323e+01
#  KMCLib: 270000 steps executed. time:     8.9757024777e+01
#  KMCLib: 280000 steps executed. time:     9.3757227876e+01
#  KMCLib: 290000 steps executed. time:     9.7797910746e+01
#  KMCLib: 300000 steps executed. time:     1.0169964647e+02
#  KMCLib: 310000 steps executed. time:     1.0560855214e+02
#  KMCLib: 320000 steps executed. time:     1.0945434610e+02
#  KMCLib: 330000 steps executed. time:     1.1335235610e+02
#  KMCLib: 340000 steps executed. time:     1.1726667279e+02
#  KMCLib: 350000 steps executed. time:     1.2123145615e+02
#  KMCLib: 360000 steps executed. time:     1.2511801566e+02
#  KMCLib: 370000 steps executed. time:     1.2894637912e+02
#  KMCLib: 380000 steps executed. time:     1.3294752193e+02
#  KMCLib: 390000 steps executed. time:     1.3711643068e+02
#  KMCLib: 400000 steps executed. time:     1.4112882457e+02
#  KMCLib: 410000 steps executed. time:     1.4521258389e+02
#  KMCLib: 420000 steps executed. time:     1.4922759319e+02
#  KMCLib: 430000 steps executed. time:     1.5323143462e+02
#  KMCLib: 440000 steps executed. time:     1.5734795564e+02
#  KMCLib: 450000 steps executed. time:     1.6146471675e+02
#  KMCLib: 460000 steps executed. time:     1.6560918569e+02
#  KMCLib: 470000 steps executed. time:     1.6940188151e+02
#  KMCLib: 480000 steps executed. time:     1.7306334261e+02
#  KMCLib: 490000 steps executed. time:     1.7689498266e+02
#  KMCLib: 500000 steps executed. time:     1.8071641166e+02
#  KMCLib: 510000 steps executed. time:     1.8427570086e+02
#  KMCLib: 520000 steps executed. time:     1.8796726175e+02
#  KMCLib: 530000 steps executed. time:     1.9165492146e+02
#  KMCLib: 540000 steps executed. time:     1.9534768355e+02
#  KMCLib: 550000 steps executed. time:     1.9900554498e+02
#  KMCLib: 560000 steps executed. time:     2.0251529694e+02
#  KMCLib: 570000 steps executed. time:     2.0602465380e+02
#  KMCLib: 580000 steps executed. time:     2.0961932406e+02
#  KMCLib: 590000 steps executed. time:     2.1316959338e+02
#  KMCLib: 600000 steps executed. time:     2.1664327517e+02
#  KMCLib: 610000 steps executed. time:     2.2046559503e+02
#  KMCLib: 620000 steps executed. time:     2.2416225006e+02
#  KMCLib: 630000 steps executed. time:     2.2793905521e+02
#  KMCLib: 640000 steps executed. time:     2.3163750242e+02
#  KMCLib: 650000 steps executed. time:     2.3526561274e+02
#  KMCLib: 660000 steps executed. time:     2.3872757359e+02
#  KMCLib: 670000 steps executed. time:     2.4218613311e+02
#  KMCLib: 680000 steps executed. time:     2.4579850075e+02
#  KMCLib: 690000 steps executed. time:     2.4941425075e+02
#  KMCLib: 700000 steps executed. time:     2.5308318542e+02
#  KMCLib: 710000 steps executed. time:     2.5699071672e+02
#  KMCLib: 720000 steps executed. time:     2.6077397492e+02
#  KMCLib: 730000 steps executed. time:     2.6480012439e+02
#  KMCLib: 740000 steps executed. time:     2.6873098973e+02
#  KMCLib: 750000 steps executed. time:     2.7289341133e+02
#  KMCLib: 760000 steps executed. time:     2.7712468066e+02
#  KMCLib: 770000 steps executed. time:     2.8109134353e+02
#  KMCLib: 780000 steps executed. time:     2.8506694354e+02
#  KMCLib: 790000 steps executed. time:     2.8898060142e+02
#  KMCLib: 800000 steps executed. time:     2.9279025545e+02
#  KMCLib: 810000 steps executed. time:     2.9647011669e+02
#  KMCLib: 820000 steps executed. time:     3.0030895518e+02
#  KMCLib: 830000 steps executed. time:     3.0413484891e+02
#  KMCLib: 840000 steps executed. time:     3.0813652923e+02
#  KMCLib: 850000 steps executed. time:     3.1201569089e+02
#  KMCLib: 860000 steps executed. time:     3.1625731033e+02
#  KMCLib: 870000 steps executed. time:     3.2028421832e+02
#  KMCLib: 880000 steps executed. time:     3.2420371222e+02
#  KMCLib: 890000 steps executed. time:     3.2814477432e+02
#  KMCLib: 900000 steps executed. time:     3.3210287474e+02
#  KMCLib: 910000 steps executed. time:     3.3605810154e+02
#  KMCLib: 920000 steps executed. time:     3.4007274000e+02
#  KMCLib: 930000 steps executed. time:     3.4400967743e+02
#  KMCLib: 940000 steps executed. time:     3.4786597489e+02
#  KMCLib: 950000 steps executed. time:     3.5181351095e+02
#  KMCLib: 960000 steps executed. time:     3.5586973585e+02
#  KMCLib: 970000 steps executed. time:     3.5988419415e+02
#  KMCLib: 980000 steps executed. time:     3.6388927064e+02
#  KMCLib: 990000 steps executed. time:     3.6783276800e+02
#  KMCLib: 1000000 steps executed. time:     3.7165083914e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.1361254704e+00
#  KMCLib: 20000 steps executed. time:     2.6520027404e+00
#  KMCLib: 30000 steps executed. time:     4.4862170613e+00
#  KMCLib: 40000 steps executed. time:     6.6161598681e+00
#  KMCLib: 50000 steps executed. time:     8.9202128670e+00
#  KMCLib: 60000 steps executed. time:     1.1429506980e+01
#  KMCLib: 70000 steps executed. time:     1.4101623588e+01
#  KMCLib: 80000 steps executed. time:     1.6991747064e+01
#  KMCLib: 90000 steps executed. time:     1.9887177822e+01
#  KMCLib: 100000 steps executed. time:     2.2846096116e+01
#  KMCLib: 110000 steps executed. time:     2.5831794172e+01
#  KMCLib: 120000 steps executed. time:     2.8935951776e+01
#  KMCLib: 130000 steps executed. time:     3.2162180911e+01
#  KMCLib: 140000 steps executed. time:     3.5537379137e+01
#  KMCLib: 150000 steps executed. time:     3.8825729665e+01
#  KMCLib: 160000 steps executed. time:     4.1977192077e+01
#  KMCLib: 170000 steps executed. time:     4.5291087121e+01
#  KMCLib: 180000 steps executed. time:     4.8628469130e+01
#  KMCLib: 190000 steps executed. time:     5.1975008513e+01
#  KMCLib: 200000 steps executed. time:     5.5407688747e+01
#  KMCLib: 210000 steps executed. time:     5.8894386684e+01
#  KMCLib: 220000 steps executed. time:     6.2205833891e+01
#  KMCLib: 230000 steps executed. time:     6.5473795544e+01
#  KMCLib: 240000 steps executed. time:     6.8809101873e+01
#  KMCLib: 250000 steps executed. time:     7.2089427649e+01
#  KMCLib: 260000 steps executed. time:     7.5485391681e+01
#  KMCLib: 270000 steps executed. time:     7.8819614124e+01
#  KMCLib: 280000 steps executed. time:     8.1934373757e+01
#  KMCLib: 290000 steps executed. time:     8.5208414946e+01
#  KMCLib: 300000 steps executed. time:     8.8383349142e+01
#  KMCLib: 310000 steps executed. time:     9.1638661232e+01
#  KMCLib: 320000 steps executed. time:     9.5029724661e+01
#  KMCLib: 330000 steps executed. time:     9.8361980440e+01
#  KMCLib: 340000 steps executed. time:     1.0181230598e+02
#  KMCLib: 350000 steps executed. time:     1.0516672363e+02
#  KMCLib: 360000 steps executed. time:     1.0858790693e+02
#  KMCLib: 370000 steps executed. time:     1.1200755138e+02
#  KMCLib: 380000 steps executed. time:     1.1537144122e+02
#  KMCLib: 390000 steps executed. time:     1.1859804489e+02
#  KMCLib: 400000 steps executed. time:     1.2189142661e+02
#  KMCLib: 410000 steps executed. time:     1.2534613736e+02
#  KMCLib: 420000 steps executed. time:     1.2871522009e+02
#  KMCLib: 430000 steps executed. time:     1.3207963793e+02
# ...
#  KMCLib: 280000 steps executed. time:     3.9298670962e+01
#  KMCLib: 290000 steps executed. time:     4.0819348609e+01
#  KMCLib: 300000 steps executed. time:     4.2345345646e+01
#  KMCLib: 310000 steps executed. time:     4.3884546842e+01
#  KMCLib: 320000 steps executed. time:     4.5392082658e+01
#  KMCLib: 330000 steps executed. time:     4.6861059376e+01
#  KMCLib: 340000 steps executed. time:     4.8334356032e+01
#  KMCLib: 350000 steps executed. time:     4.9767469513e+01
#  KMCLib: 360000 steps executed. time:     5.1244363375e+01
#  KMCLib: 370000 steps executed. time:     5.2695721461e+01
#  KMCLib: 380000 steps executed. time:     5.4141719209e+01
#  KMCLib: 390000 steps executed. time:     5.5577319570e+01
#  KMCLib: 400000 steps executed. time:     5.7080082050e+01
#  KMCLib: 410000 steps executed. time:     5.8531531413e+01
#  KMCLib: 420000 steps executed. time:     6.0018583438e+01
#  KMCLib: 430000 steps executed. time:     6.1466809251e+01
#  KMCLib: 440000 steps executed. time:     6.2890108848e+01
#  KMCLib: 450000 steps executed. time:     6.4323541288e+01
#  KMCLib: 460000 steps executed. time:     6.5830321516e+01
#  KMCLib: 470000 steps executed. time:     6.7319153827e+01
#  KMCLib: 480000 steps executed. time:     6.8797864641e+01
#  KMCLib: 490000 steps executed. time:     7.0290626929e+01
#  KMCLib: 500000 steps executed. time:     7.1808982621e+01
#  KMCLib: 510000 steps executed. time:     7.3294833926e+01
#  KMCLib: 520000 steps executed. time:     7.4794118055e+01
#  KMCLib: 530000 steps executed. time:     7.6298170105e+01
#  KMCLib: 540000 steps executed. time:     7.7790501556e+01
#  KMCLib: 550000 steps executed. time:     7.9322537188e+01
#  KMCLib: 560000 steps executed. time:     8.0854525618e+01
#  KMCLib: 570000 steps executed. time:     8.2386747818e+01
#  KMCLib: 580000 steps executed. time:     8.3898639911e+01
#  KMCLib: 590000 steps executed. time:     8.5393593224e+01
#  KMCLib: 600000 steps executed. time:     8.6856161875e+01
#  KMCLib: 610000 steps executed. time:     8.8370338231e+01
#  KMCLib: 620000 steps executed. time:     8.9869739711e+01
#  KMCLib: 630000 steps executed. time:     9.1359396064e+01
#  KMCLib: 640000 steps executed. time:     9.2863056983e+01
#  KMCLib: 650000 steps executed. time:     9.4380611790e+01
#  KMCLib: 660000 steps executed. time:     9.5849922394e+01
#  KMCLib: 670000 steps executed. time:     9.7363459198e+01
#  KMCLib: 680000 steps executed. time:     9.8836913659e+01
#  KMCLib: 690000 steps executed. time:     1.0038593496e+02
#  KMCLib: 700000 steps executed. time:     1.0186796871e+02
#  KMCLib: 710000 steps executed. time:     1.0335328261e+02
#  KMCLib: 720000 steps executed. time:     1.0481434770e+02
#  KMCLib: 730000 steps executed. time:     1.0629522176e+02
#  KMCLib: 740000 steps executed. time:     1.0780388552e+02
#  KMCLib: 750000 steps executed. time:     1.0929780034e+02
#  KMCLib: 760000 steps executed. time:     1.1080749924e+02
#  KMCLib: 770000 steps executed. time:     1.1223950174e+02
#  KMCLib: 780000 steps executed. time:     1.1371126329e+02
#  KMCLib: 790000 steps executed. time:     1.1519865625e+02
#  KMCLib: 800000 steps executed. time:     1.1672431733e+02
#  KMCLib: 810000 steps executed. time:     1.1823625223e+02
#  KMCLib: 820000 steps executed. time:     1.1973464877e+02
#  KMCLib: 830000 steps executed. time:     1.2121167258e+02
#  KMCLib: 840000 steps executed. time:     1.2270476679e+02
#  KMCLib: 850000 steps executed. time:     1.2423588868e+02
#  KMCLib: 860000 steps executed. time:     1.2575803323e+02
#  KMCLib: 870000 steps executed. time:     1.2729303651e+02
#  KMCLib: 880000 steps executed. time:     1.2886968687e+02
#  KMCLib: 890000 steps executed. time:     1.3045193681e+02
#  KMCLib: 900000 steps executed. time:     1.3200326829e+02
#  KMCLib: 910000 steps executed. time:     1.3354371439e+02
#  KMCLib: 920000 steps executed. time:     1.3509336924e+02
#  KMCLib: 930000 steps executed. time:     1.3661415714e+02
#  KMCLib: 940000 steps executed. time:     1.3809692162e+02
#  KMCLib: 950000 steps executed. time:     1.3960716016e+02
#  KMCLib: 960000 steps executed. time:     1.4108571553e+02
#  KMCLib: 970000 steps executed. time:     1.4260236701e+02
#  KMCLib: 980000 steps executed. time:     1.4414796853e+02
#  KMCLib: 990000 steps executed. time:     1.4571258478e+02
#  KMCLib: 1000000 steps executed. time:     1.4726285204e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.0404182800e+00
#  KMCLib: 20000 steps executed. time:     2.2335789405e+00
#  KMCLib: 30000 steps executed. time:     3.4834661489e+00
#  KMCLib: 40000 steps executed. time:     4.7885152397e+00
#  KMCLib: 50000 steps executed. time:     6.1134710922e+00
#  KMCLib: 60000 steps executed. time:     7.4414835454e+00
#  KMCLib: 70000 steps executed. time:     8.8088952388e+00
#  KMCLib: 80000 steps executed. time:     1.0175282983e+01
#  KMCLib: 90000 steps executed. time:     1.1561941628e+01
#  KMCLib: 100000 steps executed. time:     1.2944915995e+01
#  KMCLib: 110000 steps executed. time:     1.4341740777e+01
#  KMCLib: 120000 steps executed. time:     1.5740863281e+01
#  KMCLib: 130000 steps executed. time:     1.7119074832e+01
#  KMCLib: 140000 steps executed. time:     1.8497773884e+01
#  KMCLib: 150000 steps executed. time:     1.9897104478e+01
#  KMCLib: 160000 steps executed. time:     2.1284999198e+01
#  KMCLib: 170000 steps executed. time:     2.2683581521e+01
#  KMCLib: 180000 steps executed. time:     2.4089766677e+01
#  KMCLib: 190000 steps executed. time:     2.5540697715e+01
#  KMCLib: 200000 steps executed. time:     2.7045110886e+01
#  KMCLib: 210000 steps executed. time:     2.8529452023e+01
#  KMCLib: 220000 steps executed. time:     3.0009835228e+01
#  KMCLib: 230000 steps executed. time:     3.1475446283e+01
#  KMCLib: 240000 steps executed. time:     3.2952421944e+01
#  KMCLib: 250000 steps executed. time:     3.4452721579e+01
#  KMCLib: 260000 steps executed. time:     3.6000368897e+01
#  KMCLib: 270000 steps executed. time:     3.7541355613e+01
#  KMCLib: 280000 steps executed. time:     3.9150572008e+01
#  KMCLib: 290000 steps executed. time:     4.0770070530e+01
#  KMCLib: 300000 steps executed. time:     4.2359299050e+01
#  KMCLib: 310000 steps executed. time:     4.4001014217e+01
#  KMCLib: 320000 steps executed. time:     4.5579436011e+01
#  KMCLib: 330000 steps executed. time:     4.7204511491e+01
#  KMCLib: 340000 steps executed. time:     4.8800093940e+01
#  KMCLib: 350000 steps executed. time:     5.0454638645e+01
#  KMCLib: 360000 steps executed. time:     5.2103890779e+01
#  KMCLib: 370000 steps executed. time:     5.3757883605e+01
#  KMCLib: 380000 steps executed. time:     5.5394031601e+01
#  KMCLib: 390000 steps executed. time:     5.7078361149e+01
#  KMCLib: 400000 steps executed. time:     5.8799422181e+01
#  KMCLib: 410000 steps executed. time:     6.0559256870e+01
#  KMCLib: 420000 steps executed. time:     6.2345246487e+01
#  KMCLib: 430000 steps executed. time:     6.4163059877e+01
#  KMCLib: 440000 steps executed. time:     6.5999549779e+01
#  KMCLib: 450000 steps executed. time:     6.7831841391e+01
#  KMCLib: 460000 steps executed. time:     6.9656780510e+01
#  KMCLib: 470000 steps executed. time:     7.1514082615e+01
#  KMCLib: 480000 steps executed. time:     7.3332399869e+01
#  KMCLib: 490000 steps executed. time:     7.5229225872e+01
#  KMCLib: 500000 steps executed. time:     7.7195929672e+01
#  KMCLib: 510000 steps executed. time:     7.9167460496e+01
#  KMCLib: 520000 steps executed. time:     8.1172277582e+01
#  KMCLib: 530000 steps executed. time:     8.3272072707e+01
#  KMCLib: 540000 steps executed. time:     8.5291133591e+01
#  KMCLib: 550000 steps executed. time:     8.7481739112e+01
#  KMCLib: 560000 steps executed. time:     8.9763396512e+01
#  KMCLib: 570000 steps executed. time:     9.2114711657e+01
#  KMCLib: 580000 steps executed. time:     9.4555642718e+01
#  KMCLib: 590000 steps executed. time:     9.7144729202e+01
#  KMCLib: 600000 steps executed. time:     9.9780350004e+01
#  KMCLib: 610000 steps executed. time:     1.0260141219e+02
#  KMCLib: 620000 steps executed. time:     1.0563522597e+02
#  KMCLib: 630000 steps executed. time:     1.0875363364e+02
#  KMCLib: 640000 steps executed. time:     1.1191916669e+02
#  KMCLib: 650000 steps executed. time:     1.1543977562e+02
#  KMCLib: 660000 steps executed. time:     1.1920939993e+02
#  KMCLib: 670000 steps executed. time:     1.2355475667e+02
#  KMCLib: 680000 steps executed. time:     1.2861791955e+02
#  KMCLib: 690000 steps executed. time:     1.3448644749e+02
#  KMCLib: 700000 steps executed. time:     1.4122098603e+02
#  KMCLib: 710000 steps executed. time:     1.4946297593e+02
#  KMCLib: 720000 steps executed. time:     1.6016499723e+02
#  KMCLib: 730000 steps executed. time:     1.7605402253e+02
#  KMCLib: 737326 steps executed. time:     2.2466872140e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.0231473606e+00
#  KMCLib: 20000 steps executed. time:     2.1633350491e+00
#  KMCLib: 30000 steps executed. time:     3.3401010813e+00
#  KMCLib: 40000 steps executed. time:     4.6212369626e+00
#  KMCLib: 50000 steps executed. time:     5.9348843422e+00
#  KMCLib: 60000 steps executed. time:     7.2533650176e+00
#  KMCLib: 70000 steps executed. time:     8.5825177395e+00
#  KMCLib: 80000 steps executed. time:     9.9262638675e+00
#  KMCLib: 90000 steps executed. time:     1.1301066868e+01
#  KMCLib: 100000 steps executed. time:     1.2674321363e+01
#  KMCLib: 110000 steps executed. time:     1.4115662523e+01
#  KMCLib: 120000 steps executed. time:     1.5572995019e+01
#  KMCLib: 130000 steps executed. time:     1.7050334588e+01
#  KMCLib: 140000 steps executed. time:     1.8571963694e+01
#  KMCLib: 150000 steps executed. time:     2.0072558255e+01
#  KMCLib: 160000 steps executed. time:     2.1636498356e+01
#  KMCLib: 170000 steps executed. time:     2.3284541960e+01
#  KMCLib: 180000 steps executed. time:     2.4939226864e+01
#  KMCLib: 190000 steps executed. time:     2.6631640841e+01
#  KMCLib: 200000 steps executed. time:     2.8364619830e+01
#  KMCLib: 210000 steps executed. time:     3.0210237294e+01
#  KMCLib: 220000 steps executed. time:     3.2182117499e+01
#  KMCLib: 230000 steps executed. time:     3.4314594804e+01
#  KMCLib: 240000 steps executed. time:     3.6510989050e+01
#  KMCLib: 250000 steps executed. time:     3.8875092745e+01
#  KMCLib: 260000 steps executed. time:     4.1523420406e+01
#  KMCLib: 270000 steps executed. time:     4.4391468690e+01
#  KMCLib: 280000 steps executed. time:     4.7770955052e+01
#  KMCLib: 290000 steps executed. time:     5.1807828762e+01
#  KMCLib: 300000 steps executed. time:     5.6618803395e+01
#  KMCLib: 310000 steps executed. time:     6.2191965400e+01
#  KMCLib: 320000 steps executed. time:     7.0672659062e+01
#  KMCLib: 330000 steps executed. time:     8.7303186398e+01
#  KMCLib: 335951 steps executed. time:     1.4164022807e+02
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.0180673111e+00
#  KMCLib: 20000 steps executed. time:     2.1504496306e+00
#  KMCLib: 30000 steps executed. time:     3.3273190416e+00
#  KMCLib: 40000 steps executed. time:     4.6110578487e+00
#  KMCLib: 50000 steps executed. time:     5.9067262294e+00
#  KMCLib: 60000 steps executed. time:     7.2511850398e+00
#  KMCLib: 70000 steps executed. time:     8.6605436510e+00
#  KMCLib: 80000 steps executed. time:     1.0081726520e+01
#  KMCLib: 90000 steps executed. time:     1.1545473253e+01
#  KMCLib: 100000 steps executed. time:     1.3061738644e+01
#  KMCLib: 110000 steps executed. time:     1.4667998013e+01
#  KMCLib: 120000 steps executed. time:     1.6386547749e+01
#  KMCLib: 130000 steps executed. time:     1.8192472238e+01
#  KMCLib: 140000 steps executed. time:     2.0050301086e+01
#  KMCLib: 150000 steps executed. time:     2.2024403785e+01
#  KMCLib: 160000 steps executed. time:     2.4099015660e+01
#  KMCLib: 170000 steps executed. time:     2.6391736084e+01
#  KMCLib: 180000 steps executed. time:     2.8951753039e+01
#  KMCLib: 190000 steps executed. time:     3.2139190883e+01
#  KMCLib: 200000 steps executed. time:     3.6143448691e+01
#  KMCLib: 210000 steps executed. time:     4.2121393695e+01
#  KMCLib: 220000 steps executed. time:     5.5907458728e+01
#  KMCLib: 222021 steps executed. time:     7.1148369441e+01
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.0286620159e+00
#  KMCLib: 20000 steps executed. time:     2.1444569252e+00
#  KMCLib: 30000 steps executed. time:     3.3157606027e+00
#  KMCLib: 40000 steps executed. time:     4.5360506583e+00
#  KMCLib: 50000 steps executed. time:     5.7841914359e+00
#  KMCLib: 60000 steps executed. time:     7.0929504982e+00
#  KMCLib: 70000 steps executed. time:     8.4583575435e+00
#  KMCLib: 80000 steps executed. time:     9.8922778827e+00
#  KMCLib: 90000 steps executed. time:     1.1471126509e+01
#  KMCLib: 100000 steps executed. time:     1.3152927165e+01
#  KMCLib: 110000 steps executed. time:     1.4898586296e+01
#  KMCLib: 120000 steps executed. time:     1.6819904265e+01
#  KMCLib: 130000 steps executed. time:     1.8999875556e+01
#  KMCLib: 140000 steps executed. time:     2.1598210963e+01
#  KMCLib: 150000 steps executed. time:     2.5086012253e+01
#  KMCLib: 160000 steps executed. time:     3.1090595764e+01
#  KMCLib: 168016 steps executed. time:     7.0689283093e+01
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.0192984267e+00
#  KMCLib: 20000 steps executed. time:     2.1622231626e+00
#  KMCLib: 30000 steps executed. time:     3.3703025570e+00
#  KMCLib: 40000 steps executed. time:     4.6291531740e+00
#  KMCLib: 50000 steps executed. time:     5.9502598273e+00
#  KMCLib: 60000 steps executed. time:     7.3476662515e+00
#  KMCLib: 70000 steps executed. time:     8.8301409762e+00
#  KMCLib: 80000 steps executed. time:     1.0499622976e+01
#  KMCLib: 90000 steps executed. time:     1.2449560839e+01
#  KMCLib: 100000 steps executed. time:     1.4817756529e+01
#  KMCLib: 110000 steps executed. time:     1.7935065967e+01
#  KMCLib: 120000 steps executed. time:     2.4058360483e+01
#  KMCLib: 123446 steps executed. time:     4.3257363500e+01
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     1.0194154328e+00
#  KMCLib: 20000 steps executed. time:     2.1351335975e+00
#  KMCLib: 30000 steps executed. time:     3.3415370597e+00
#  KMCLib: 40000 steps executed. time:     4.6276186079e+00
#  KMCLib: 50000 steps executed. time:     6.0510200265e+00
#  KMCLib: 60000 steps executed. time:     7.6303035059e+00
#  KMCLib: 70000 steps executed. time:     9.4394398306e+00
#  KMCLib: 80000 steps executed. time:     1.1556933680e+01
#  KMCLib: 90000 steps executed. time:     1.4383638210e+01
#  KMCLib: 100000 steps executed. time:     2.0183390007e+01
#  KMCLib: 103671 steps executed. time:     4.1572414830e+01
#  KMCLib: setting up the backend C++ object.
#  KMCLib: Running for 1000000 steps, starting from time: 0.000000
#
#  KMCLib: 10000 steps executed. time:     9.9026244699e-01
#  KMCLib: 20000 steps executed. time:     2.1180867326e+00
#  KMCLib: 30000 steps executed. time:     3.3674109782e+00
#  KMCLib: 40000 steps executed. time:     4.7179193176e+00
#  KMCLib: 50000 steps executed. time:     6.2442931241e+00
#  KMCLib: 60000 steps executed. time:     8.0231870716e+00
#  KMCLib: 70000 steps executed. time:     1.0301977187e+01
#  KMCLib: 80000 steps executed. time:     1.3946885187e+01
#  KMCLib: 87676 steps executed. time:     5.3502440745e+01

# %%
plot(yv,TOF,':o')
plot(yv,QO,'-o')
plot(yv,QCO,'--o')
legend(['TOF','$\Theta_O$','$\Theta_{CO}$'])
xlabel('$y_{CO}$')
show()

# %% [markdown]
# These results compare well with Figure 4 of ZGB:
# ![image.png](attachment:image.png)
